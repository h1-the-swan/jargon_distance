# %%
from nltk import word_tokenize, ngrams

# %%
with open('./text_data/shakespeare/1786.txt.utf-8', 'r') as f:
    txt = f.read()

# %%
tokens = word_tokenize(txt)

# %%
ng = ngrams(tokens, 1)

# %%
from collections import Counter
c = Counter(ng)

# %%
c.most_common(60)
# Out:
# [((',',), 2012),
#  (('.',), 1946),
#  (('I',), 704),
#  (('the',), 622),
#  ((';',), 586),
#  (('and',), 535),
#  (('you',), 476),
#  (('of',), 415),
#  (('to',), 415),
#  (('a',), 412),
#  (('in',), 300),
#  (('is',), 296),
#  (('?',), 289),
#  (('that',), 283),
#  (('not',), 266),
#  (('my',), 237),
#  (('me',), 231),
#  (('ROSALIND',), 217),
#  (("'d",), 193),
#  (('for',), 189),
#  (('he',), 189),
#  (('be',), 181),
#  (('with',), 179),
#  (('it',), 177),
#  (('your',), 176),
#  (('have',), 163),
#  (('his',), 156),
#  (('And',), 154),
#  (('him',), 153),
#  (('will',), 147),
#  (('this',), 143),
#  (("'s",), 142),
#  (('ORLANDO',), 138),
#  (('as',), 135),
#  (('but',), 126),
#  (('CELIA',), 123),
#  (('thou',), 122),
#  (('!',), 122),
#  (('so',), 115),
#  (('love',), 114),
#  (('do',), 111),
#  (('no',), 104),
#  (('her',), 103),
#  (('good',), 98),
#  (('are',), 98),
#  (('man',), 92),
#  (('thee',), 89),
#  (('TOUCHSTONE',), 85),
#  (('all',), 84),
#  (('was',), 83),
#  (('if',), 80),
#  (('am',), 73),
#  (('more',), 72),
#  (("'",), 72),
#  (('JAQUES',), 72),
#  (('would',), 69),
#  (('The',), 69),
#  (('thy',), 66),
#  (('That',), 65),
#  (('But',), 65)]

# %%
# import codecs
# fnames = ['./text_data/shakespeare/5702.txt', './text_data/shakespeare/5724.txt', 
#           './text_data/kipling/3272.txt', './text_data/kipling/3276.txt']
# groups = ['shakespeare1', 'shakespeare2', 'kipling1', 'kipling2']
# term_counts = []
# for fname in fnames:
#     with codecs.open(fname, 'r', encoding='utf8') as f:
#         txt = f.read()
#     txt = txt.lower()
#     tokens = word_tokenize(txt)
#     ng = ngrams(tokens, 1)
#     term_counts.append(Counter(ng))

# %%
import codecs
fnames = ['./text_data/shakespeare/1786.txt.utf-8', './text_data/shakespeare/1793.txt.utf-8',
#          './text_data/carroll/12-0.txt', './text_data/carroll/13-0.txt',
         './text_data/sawyer/74-0.txt', './text_data/sawyer/76-0.txt',
         './text_data/dickens/pg19337.txt', './text_data/dickens/pg730.txt']
groups = ['William Shakespeare - As You Like It', 'William Shakespeare - Othello', 
#           'Lewis Carroll - Through the Looking Glass', 'Lewis Carroll - The Hunting of the Snark', 
          'Mark Twain - The Adventures of Tom Sawyer', 'Mark Twain - The Adventures of Huckleberry Finn',
          'Charles Dickens - A Christmas Carol', 'Charles Dickens - Oliver Twist']
term_counts = []
for fname in fnames:
    with codecs.open(fname, 'r', encoding='utf8') as f:
        txt = f.read()
    txt = txt.lower()
    tokens = word_tokenize(txt)
    ng = ngrams(tokens, 1)
    term_counts.append(Counter(ng))

# %%
term_count_dict = {}
group_map = {}
for i, fname in enumerate(fnames):
    term_count_dict[fname] = term_counts[i]
    group_map[fname] = groups[i]

# %%
from jargon_distance import JargonDistance

# %%
j = JargonDistance(term_counts=term_count_dict, group_map=group_map)
j.calculate_jargon_distance()
# Out:
# 21:31:00 __main__.jargon_distance.JargonDistance.163 INFO : Calculating jargon distance...
# 21:31:01 __main__.jargon_distance.JargonDistance.175 INFO : done. Took 0.54 seconds
# defaultdict(dict,
#             {'Charles Dickens - A Christmas Carol': {'Charles Dickens - A Christmas Carol': 0.0,
#               'Charles Dickens - Oliver Twist': 0.08135338382515156,
#               'Mark Twain - The Adventures of Huckleberry Finn': 0.093481267284584946,
#               'Mark Twain - The Adventures of Tom Sawyer': 0.077315299083304478,
#               'William Shakespeare - As You Like It': 0.086700035950757814,
#               'William Shakespeare - Othello': 0.09317211609549414},
#              'Charles Dickens - Oliver Twist': {'Charles Dickens - A Christmas Carol': 0.035976160349689534,
#               'Charles Dickens - Oliver Twist': 0.0,
#               'Mark Twain - The Adventures of Huckleberry Finn': 0.061825425610769202,
#               'Mark Twain - The Adventures of Tom Sawyer': 0.052160515899584037,
#               'William Shakespeare - As You Like It': 0.052160382364547342,
#               'William Shakespeare - Othello': 0.059309058518327129},
#              'Mark Twain - The Adventures of Huckleberry Finn': {'Charles Dickens - A Christmas Carol': 0.063234512154527023,
#               'Charles Dickens - Oliver Twist': 0.076013643278823428,
#               'Mark Twain - The Adventures of Huckleberry Finn': 0.0,
#               'Mark Twain - The Adventures of Tom Sawyer': 0.047009959566679083,
#               'William Shakespeare - As You Like It': 0.06932995435027367,
#               'William Shakespeare - Othello': 0.083219814245839796},
#              'Mark Twain - The Adventures of Tom Sawyer': {'Charles Dickens - A Christmas Carol': 0.043702325684456422,
#               'Charles Dickens - Oliver Twist': 0.058592521433082911,
#               'Mark Twain - The Adventures of Huckleberry Finn': 0.04301541384534735,
#               'Mark Twain - The Adventures of Tom Sawyer': 0.0,
#               'William Shakespeare - As You Like It': 0.059929098549459381,
#               'William Shakespeare - Othello': 0.067599463941744209},
#              'William Shakespeare - As You Like It': {'Charles Dickens - A Christmas Carol': 0.10833430803810673,
#               'Charles Dickens - Oliver Twist': 0.11795182250809322,
#               'Mark Twain - The Adventures of Huckleberry Finn': 0.12602303443626828,
#               'Mark Twain - The Adventures of Tom Sawyer': 0.12477357590133964,
#               'William Shakespeare - As You Like It': 0.0,
#               'William Shakespeare - Othello': 0.063485642830664379},
#              'William Shakespeare - Othello': {'Charles Dickens - A Christmas Carol': 0.10511374668548035,
#               'Charles Dickens - Oliver Twist': 0.11625453671588715,
#               'Mark Twain - The Adventures of Huckleberry Finn': 0.12435946322749281,
#               'Mark Twain - The Adventures of Tom Sawyer': 0.12184820304272592,
#               'William Shakespeare - As You Like It': 0.059380069399602609,
#               'William Shakespeare - Othello': 0.0}})

# %%
term_counts[3].most_common()
# Out:
# [((u',',), 8050),
#  ((u'and',), 6366),
#  ((u'the',), 4899),
#  ((u'.',), 4027),
#  ((u'i',), 3609),
#  ((u'a',), 2972),
#  ((u'to',), 2917),
#  ((u'it',), 2496),
#  ((u'was',), 2069),
#  ((u"n't",), 1917),
#  ((u'he',), 1829),
#  ((u'of',), 1652),
#  ((u'\u201c',), 1637),
#  ((u'\u201d',), 1620),
#  ((u';',), 1562),
#  ((u'you',), 1466),
#  ((u'in',), 1450),
#  ((u'that',), 1197),
#  ((u'--',), 1122),
#  ((u'but',), 1035),
#  ((u"'s",), 988),
#  ((u'so',), 961),
#  ((u'we',), 952),
#  ((u'on',), 875),
#  ((u'for',), 851),
#  ((u'all',), 840),
#  ((u'up',), 833),
#  ((u'they',), 820),
#  ((u'out',), 803),
#  ((u'me',), 745),
#  ((u'?',), 736),
#  ((u'him',), 703),
#  ((u'do',), 689),
#  ((u'there',), 640),
#  ((u'says',), 637),
#  ((u'got',), 613),
#  ((u'then',), 593),
#  ((u'no',), 580),
#  ((u"'",), 574),
#  ((u'would',), 563),
#  ((u'his',), 553),
#  ((u'she',), 543),
#  ((u'as',), 543),
#  ((u'with',), 534),
#  ((u'had',), 527),
#  ((u'!',), 517),
#  ((u'them',), 512),
#  ((u'could',), 501),
#  ((u'said',), 485),
#  ((u'see',), 474),
#  ((u'down',), 467),
#  ((u'what',), 461),
#  ((u'did',), 449),
#  ((u'when',), 430),
#  ((u':',), 429),
#  ((u'about',), 420),
#  ((u'my',), 413),
#  ((u'well',), 408),
#  ((u'if',), 406),
#  ((u'at',), 404),
#  ((u'by',), 401),
#  ((u'come',), 397),
#  ((u'one',), 374),
#  ((u'jim',), 368),
#  ((u'be',), 365),
#  ((u'her',), 349),
#  ((u"'d",), 338),
#  ((u'get',), 332),
#  ((u'or',), 318),
#  ((u'time',), 310),
#  ((u'is',), 302),
#  ((u'right',), 296),
#  ((u'went',), 294),
#  ((u'over',), 284),
#  ((u'off',), 284),
#  ((u"'ll",), 279),
#  ((u'ai',), 276),
#  ((u'just',), 273),
#  ((u'war',), 273),
#  ((u'go',), 272),
#  ((u'good',), 271),
#  ((u'old',), 263),
#  ((u'way',), 262),
#  ((u'like',), 259),
#  ((u'around',), 259),
#  ((u'de',), 252),
#  ((u'this',), 251),
#  ((u'know',), 248),
#  ((u'now',), 246),
#  ((u'tom',), 234),
#  ((u'en',), 234),
#  ((u'along',), 230),
#  ((u'because',), 222),
#  ((u'done',), 221),
#  ((u'back',), 217),
#  ((u'man',), 215),
#  ((u'ever',), 210),
#  ((u'why',), 206),
#  ((u'little',), 203),
#  ((u'your',), 199),
#  ((u'some',), 198),
#  ((u'how',), 197),
#  ((u'never',), 194),
#  ((u'here',), 191),
#  ((u'say',), 190),
#  ((u'more',), 190),
#  ((u'again',), 187),
#  ((u'two',), 187),
#  ((u'too',), 186),
#  ((u'have',), 181),
#  ((u'away',), 180),
#  ((u'tell',), 178),
#  ((u'nothing',), 177),
#  ((u'going',), 177),
#  ((u'made',), 175),
#  ((u'take',), 171),
#  ((u'took',), 169),
#  ((u'from',), 166),
#  ((u'make',), 166),
#  ((u'us',), 162),
#  ((u'not',), 162),
#  ((u'pretty',), 161),
#  ((u'before',), 161),
#  ((u'any',), 159),
#  ((u'king',), 158),
#  ((u'nigger',), 155),
#  ((u'their',), 153),
#  ((u'let',), 153),
#  ((u'duke',), 150),
#  ((u'where',), 149),
#  ((u'want',), 148),
#  ((u'long',), 147),
#  ((u'an',), 146),
#  ((u'thing',), 144),
#  ((u'told',), 144),
#  ((u'set',), 142),
#  ((u'river',), 141),
#  ((u'after',), 141),
#  ((u'give',), 138),
#  ((u'into',), 137),
#  ((u'think',), 136),
#  ((u'put',), 136),
#  ((u'most',), 135),
#  ((u'been',), 135),
#  ((u'kind',), 135),
#  ((u'can',), 133),
#  ((u'till',), 133),
#  ((u'people',), 128),
#  ((u'night',), 124),
#  ((u'look',), 123),
#  ((u'every',), 119),
#  ((u'reckon',), 119),
#  ((u"'ve",), 117),
#  ((u'only',), 116),
#  ((u'things',), 116),
#  ((u"'m",), 115),
#  ((u'head',), 115),
#  ((u'raft',), 114),
#  ((u'other',), 113),
#  ((u'which',), 113),
#  ((u'enough',), 110),
#  ((u'town',), 109),
#  ((u'place',), 109),
#  ((u'our',), 104),
#  ((u'another',), 103),
#  ((u'day',), 103),
#  ((u'three',), 102),
#  ((u'soon',), 101),
#  ((u'very',), 98),
#  ((u'last',), 98),
#  ((u'much',), 97),
#  ((u'ca',), 96),
#  ((u'everybody',), 95),
#  ((u'always',), 94),
#  ((u'big',), 94),
#  ((u'first',), 94),
#  ((u'minute',), 94),
#  ((u"'re",), 93),
#  ((u'knowed',), 93),
#  ((u'better',), 93),
#  ((u'such',), 92),
#  ((u'something',), 92),
#  ((u'run',), 92),
#  ((u'hear',), 92),
#  ((u'wanted',), 92),
#  ((u'next',), 88),
#  ((u'looked',), 88),
#  ((u'huck',), 87),
#  ((u'gone',), 87),
#  ((u'dat',), 87),
#  ((u'than',), 86),
#  ((u'chapter',), 86),
#  ((u'keep',), 85),
#  ((u'anything',), 85),
#  ((u'trouble',), 83),
#  ((u'through',), 83),
#  ((u'heard',), 81),
#  ((u'yes',), 81),
#  ((u'under',), 81),
#  ((u'money',), 80),
#  ((u'dey',), 80),
#  ((u'house',), 80),
#  ((u'still',), 79),
#  ((u'mile',), 78),
#  ((u'door',), 76),
#  ((u'mind',), 76),
#  ((u'miss',), 76),
#  ((u'side',), 75),
#  ((u'reckoned',), 75),
#  ((u'found',), 74),
#  ((u'nobody',), 74),
#  ((u'laid',), 74),
#  ((u'oh',), 73),
#  ((u'bed',), 72),
#  ((u'dead',), 72),
#  ((u'hands',), 72),
#  ((u'anybody',), 71),
#  ((u'begun',), 71),
#  ((u'mighty',), 71),
#  ((u'men',), 70),
#  ((u'water',), 70),
#  ((u'hand',), 70),
#  ((u'who',), 69),
#  ((u'talk',), 69),
#  ((u'dark',), 69),
#  ((u'everything',), 69),
#  ((u'hai',), 69),
#  ((u'maybe',), 68),
#  ((u'thought',), 67),
#  ((u'these',), 67),
#  ((u'must',), 67),
#  ((u'myself',), 66),
#  ((u'woods',), 66),
#  ((u'might',), 65),
#  ((u'work',), 64),
#  ((u'comes',), 64),
#  ((u'half',), 64),
#  ((u'canoe',), 64),
#  ((u'wo',), 63),
#  ((u'same',), 63),
#  ((u"'em",), 62),
#  ((u'home',), 62),
#  ((u'nor',), 61),
#  ((u'pap',), 61),
#  ((u'are',), 60),
#  ((u'left',), 60),
#  ((u'mary',), 60),
#  ((u'body',), 59),
#  ((u'yet',), 59),
#  ((u'use',), 58),
#  ((u'find',), 58),
#  ((u'dollars',), 58),
#  ((u'behind',), 58),
#  ((u'lot',), 57),
#  ((u'aunt',), 57),
#  ((u'o',), 57),
#  ((u'young',), 57),
#  ((u'lay',), 57),
#  ((u'has',), 56),
#  ((u'started',), 55),
#  ((u'being',), 54),
#  ((u'will',), 54),
#  ((u'towards',), 54),
#  ((u'looking',), 53),
#  ((u'foot',), 53),
#  ((u'sawyer',), 52),
#  ((u'judged',), 52),
#  ((u'saying',), 52),
#  ((u'poor',), 51),
#  ((u'somebody',), 51),
#  ((u'while',), 51),
#  ((u'help',), 50),
#  ((u'show',), 50),
#  ((u'struck',), 50),
#  ((u'sally',), 50),
#  ((u'coming',), 50),
#  ((u'fetch',), 49),
#  ((u'light',), 49),
#  ((u'git',), 49),
#  ((u'does',), 49),
#  ((u'boy',), 49),
#  ((u'easy',), 48),
#  ((u'morning',), 48),
#  ((u'whole',), 48),
#  ((u'rest',), 47),
#  ((u'many',), 47),
#  ((u'sometimes',), 47),
#  ((u'getting',), 47),
#  ((u'uncle',), 47),
#  ((u'widow',), 47),
#  ((u'mean',), 47),
#  ((u'niggers',), 47),
#  ((u'kept',), 47),
#  ((u'room',), 46),
#  ((u'glad',), 46),
#  ((u'world',), 46),
#  ((u'seen',), 46),
#  ((u"'bout",), 46),
#  ((u'er',), 46),
#  ((u'jane',), 46),
#  ((u'times',), 46),
#  ((u'both',), 46),
#  ((u'anyway',), 45),
#  ((u'piece',), 45),
#  ((u'...',), 45),
#  ((u'himself',), 44),
#  ((u'name',), 44),
#  ((u'white',), 43),
#  ((u'feel',), 43),
#  ((u'bank',), 43),
#  ((u'doctor',), 43),
#  ((u'without',), 43),
#  ((u'own',), 42),
#  ((u'buck',), 42),
#  ((u'eyes',), 42),
#  ((u'turn',), 42),
#  ((u'ten',), 42),
#  ((u'course',), 42),
#  ((u'island',), 42),
#  ((u'four',), 42),
#  ((u'days',), 41),
#  ((u'new',), 41),
#  ((u'bad',), 41),
#  ((u'used',), 41),
#  ((u'ready',), 41),
#  ((u'try',), 41),
#  ((u'stood',), 40),
#  ((u'start',), 40),
#  ((u'ben',), 40),
#  ((u'chance',), 40),
#  ((u'stand',), 40),
#  ((u'free',), 40),
#  ((u'gwyne',), 40),
#  ((u'it.',), 40),
#  ((u'stay',), 40),
#  ((u'sight',), 40),
#  ((u'best',), 40),
#  ((u'turned',), 40),
#  ((u'open',), 39),
#  ((u'_you_',), 39),
#  ((u'hid',), 39),
#  ((u'middle',), 39),
#  ((u'six',), 39),
#  ((u'couple',), 38),
#  ((u'fetched',), 37),
#  ((u'fool',), 37),
#  ((u'full',), 37),
#  ((u'face',), 37),
#  ((u'stopped',), 37),
#  ((u'amongst',), 37),
#  ((u'blame',), 37),
#  ((u'shore',), 37),
#  ((u'seem',), 37),
#  ((u'sound',), 36),
#  ((u'across',), 36),
#  ((u'though',), 36),
#  ((u'tried',), 36),
#  ((u'country',), 36),
#  ((u'wait',), 35),
#  ((u'business',), 35),
#  ((u'hour',), 35),
#  ((u'slow',), 35),
#  ((u"t'other",), 35),
#  ((u'awful',), 35),
#  ((u'hundred',), 35),
#  ((u'year',), 35),
#  ((u'front',), 34),
#  ((u'family',), 34),
#  ((u'considerable',), 34),
#  ((u'thinking',), 34),
#  ((u'end',), 34),
#  ((u'sure',), 34),
#  ((u'asleep',), 33),
#  ((u'called',), 33),
#  ((u'kill',), 33),
#  ((u'leave',), 33),
#  ((u'boat',), 33),
#  ((u'trying',), 33),
#  ((u'below',), 33),
#  ((u'word',), 33),
#  ((u'killed',), 33),
#  ((u'read',), 33),
#  ((u'sleep',), 33),
#  ((u'thousand',), 33),
#  ((u'laying',), 33),
#  ((u'ways',), 32),
#  ((u'talking',), 32),
#  ((u'clothes',), 32),
#  ((u'bet',), 32),
#  ((u'low',), 32),
#  ((u'else',), 32),
#  ((u'gentleman',), 32),
#  ((u'lit',), 32),
#  ((u'breakfast',), 32),
#  ((u'allowed',), 32),
#  ((u'hold',), 32),
#  ((u'asked',), 32),
#  ((u'idea',), 32),
#  ((u'black',), 32),
#  ((u'luck',), 31),
#  ((u'eat',), 31),
#  ((u'shoved',), 31),
#  ((u'straight',), 31),
#  ((u'woman',), 31),
#  ((u'five',), 31),
#  ((u'judge',), 31),
#  ((u'drunk',), 31),
#  ((u'gun',), 31),
#  ((u'steamboat',), 31),
#  ((u'cabin',), 30),
#  ((u'doan',), 30),
#  ((u'sick',), 30),
#  ((u'makes',), 30),
#  ((u'fix',), 30),
#  ((u'answer',), 30),
#  ((u'a-going',), 30),
#  ((u'book',), 30),
#  ((u'bit',), 30),
#  ((u'talked',), 30),
#  ((u'comfortable',), 30),
#  ((u'wuz',), 30),
#  ((u'showed',), 30),
#  ((u'goes',), 29),
#  ((u'second',), 29),
#  ((u'high',), 29),
#  ((u'wish',), 29),
#  ((u'steal',), 29),
#  ((u'live',), 29),
#  ((u'shot',), 29),
#  ((u'floor',), 29),
#  ((u'road',), 29),
#  ((u'dogs',), 29),
#  ((u'arms',), 28),
#  ((u'safe',), 28),
#  ((u'once',), 28),
#  ((u'_was_',), 28),
#  ((u'life',), 28),
#  ((u'folks',), 28),
#  ((u'runaway',), 28),
#  ((u'boys',), 28),
#  ((u'write',), 28),
#  ((u'doing',), 28),
#  ((u'mars',), 27),
#  ((u'shut',), 27),
#  ((u'hat',), 27),
#  ((u'dog',), 27),
#  ((u'scared',), 27),
#  ((u'silas',), 27),
#  ((u'call',), 27),
#  ((u'watson',), 27),
#  ((u'quick',), 27),
#  ((u'candle',), 27),
#  ((u'dropped',), 27),
#  ((u'believe',), 27),
#  ((u'den',), 27),
#  ((u'fire',), 27),
#  ((u'watch',), 26),
#  ((u'round',), 26),
#  ((u'heart',), 26),
#  ((u'log',), 26),
#  ((u'felt',), 26),
#  ((u'broke',), 26),
#  ((u'nights',), 26),
#  ((u'sid',), 26),
#  ((u'died',), 26),
#  ((u'supper',), 25),
#  ((u"'uz",), 25),
#  ((u'hardly',), 25),
#  ((u'ask',), 25),
#  ((u"s'i",), 25),
#  ((u'father',), 25),
#  ((u'window',), 25),
#  ((u'tin',), 25),
#  ((u'land',), 25),
#  ((u'satisfied',), 25),
#  ((u'brother',), 25),
#  ((u'crowd',), 25),
#  ((u'cold',), 25),
#  ((u'sorry',), 25),
#  ((u'women',), 25),
#  ((u'hard',), 25),
#  ((u'wrote',), 25),
#  ((u'paper',), 25),
#  ((u'different',), 25),
#  ((u'sign',), 24),
#  ((u'against',), 24),
#  ((u"'t",), 24),
#  ((u'gang',), 24),
#  ((u'agin',), 24),
#  ((u'saw',), 24),
#  ((u"'n",), 24),
#  ((u'slid',), 24),
#  ((u'worth',), 24),
#  ((u'words',), 24),
#  ((u'together',), 24),
#  ((u'ole',), 24),
#  ((u'person',), 24),
#  ((u'loose',), 23),
#  ((u'none',), 23),
#  ((u'hung',), 23),
#  ((u'ground',), 23),
#  ((u'somehow',), 23),
#  ((u'rich',), 23),
#  ((u'jumped',), 23),
#  ((u'dig',), 23),
#  ((u'_is_',), 23),
#  ((u'stole',), 23),
#  ((u'close',), 23),
#  ((u'village',), 23),
#  ((u'waited',), 22),
#  ((u'hide',), 22),
#  ((u'forgot',), 22),
#  ((u'may',), 22),
#  ((u'stop',), 22),
#  ((u'rats',), 22),
#  ((u'care',), 22),
#  ((u'shook',), 22),
#  ((u'whilst',), 22),
#  ((u'bill',), 22),
#  ((u'pie',), 22),
#  ((u'yonder',), 22),
#  ((u'camp',), 22),
#  ((u'table',), 22),
#  ((u'fifteen',), 22),
#  ((u'far',), 22),
#  ((u'minutes',), 22),
#  ((u'fixed',), 22),
#  ((u"didn't",), 22),
#  ((u'daylight',), 22),
#  ((u'happened',), 22),
#  ((u'hurt',), 22),
#  ((u'hurry',), 21),
#  ((u'mo',), 21),
#  ((u'cut',), 21),
#  ((u'running',), 21),
#  ((u'aboard',), 21),
#  ((u'lantern',), 21),
#  ((u'hair',), 21),
#  ((u'late',), 21),
#  ((u'ladder',), 21),
#  ((u'girls',), 21),
#  ((u'hanging',), 21),
#  ((u'tied',), 21),
#  ((u'line',), 21),
#  ((u'prisoner',), 21),
#  ((u'matter',), 21),
#  ((u'plan',), 21),
#  ((u'harvey',), 21),
#  ((u'shirt',), 21),
#  ((u'current',), 21),
#  ((u'places',), 21),
#  ((u'whether',), 21),
#  ((u'years',), 21),
#  ((u'sudden',), 21),
#  ((u'cents',), 21),
#  ((u'corner',), 21),
#  ((u'sir',), 21),
#  ((u'ashore',), 21),
#  ((u'peter',), 21),
#  ((u'each',), 21),
#  ((u'mr.',), 21),
#  ((u'jis',), 21),
#  ((u'alone',), 20),
#  ((u'hole',), 20),
#  ((u'ahead',), 20),
#  ((u'throw',), 20),
#  ((u'_him_',), 20),
#  ((u'(',), 20),
#  ((u'fell',), 20),
#  ((u'children',), 20),
#  ((u'ought',), 20),
#  ((u')',), 20),
#  ((u'horse',), 20),
#  ((u'lightning',), 20),
#  ((u'wigwam',), 20),
#  ((u'harm',), 20),
#  ((u'mouth',), 20),
#  ((u'fast',), 20),
#  ((u'perfectly',), 20),
#  ((u'heads',), 20),
#  ((u'stairs',), 20),
#  ((u'plenty',), 20),
#  ((u'blow',), 20),
#  ((u'sweat',), 20),
#  ((u'catched',), 19),
#  ((u'feeling',), 19),
#  ((u'worked',), 19),
#  ((u'bag',), 19),
#  ((u'powerful',), 19),
#  ((u'seemed',), 19),
#  ((u'cried',), 19),
#  ((u'top',), 19),
#  ((u'dah',), 19),
#  ((u'trees',), 19),
#  ((u'difference',), 19),
#  ((u'_he_',), 19),
#  ((u'bottom',), 19),
#  ((u'dear',), 19),
#  ((u'slipped',), 19),
#  ((u'looky',), 19),
#  ((u'quiet',), 19),
#  ((u"s'pose",), 19),
#  ((u'dinner',), 19),
#  ((u'_me_',), 19),
#  ((u'girl',), 19),
#  ((u'goodness',), 19),
#  ((u'leg',), 19),
#  ((u'william',), 19),
#  ((u'skiff',), 19),
#  ((u'listened',), 19),
#  ((u'tree',), 19),
#  ((u'solid',), 19),
#  ((u'ther',), 19),
#  ((u"reck'n",), 19),
#  ((u'sold',), 19),
#  ((u"warn't",), 19),
#  ((u'fog',), 19),
#  ((u'lost',), 19),
#  ((u'thick',), 19),
#  ((u'noticed',), 19),
#  ((u'need',), 19),
#  ((u'between',), 19),
#  ((u'locked',), 18),
#  ((u'honest',), 18),
#  ((u'week',), 18),
#  ((u'wished',), 18),
#  ((u'notice',), 18),
#  ((u'busted',), 18),
#  ((u'george',), 18),
#  ((u'drownded',), 18),
#  ((u'shove',), 18),
#  ((u'chile',), 18),
#  ((u'catch',), 18),
#  ((u'nice',), 18),
#  ((u'clean',), 18),
#  ((u'horses',), 18),
#  ((u'tears',), 18),
#  ((u'deep',), 18),
#  ((u'regular',), 18),
#  ((u'coffin',), 18),
#  ((u'further',), 18),
#  ((u'friend',), 18),
#  ((u'jump',), 18),
#  ((u'stick',), 18),
#  ((u'ago',), 18),
#  ((u'wid',), 18),
#  ((u'preacher',), 18),
#  ((u'guns',), 18),
#  ((u'am',), 18),
#  ((u'sell',), 18),
#  ((u'hunt',), 18),
#  ((u'rope',), 18),
#  ((u'job',), 18),
#  ((u'tired',), 18),
#  ((u'yourself',), 17),
#  ((u'sherburn',), 17),
#  ((u'besides',), 17),
#  ((u'born',), 17),
#  ((u'ones',), 17),
#  ((u'_did_',), 17),
#  ((u'above',), 17),
#  ((u'send',), 17),
#  ((u'cat',), 17),
#  ((u'rain',), 17),
#  ((u'longer',), 17),
#  ((u'stuck',), 17),
#  ((u'bust',), 17),
#  ((u'clear',), 17),
#  ((u'natural',), 17),
#  ((u'wall',), 17),
#  ((u'neck',), 17),
#  ((u'die',), 17),
#  ((u'finn',), 17),
#  ((u'church',), 17),
#  ((u'beautiful',), 17),
#  ((u'raised',), 17),
#  ((u'letter',), 17),
#  ((u'spread',), 17),
#  ((u'sort',), 17),
#  ((u'store',), 17),
#  ((u'thinks',), 17),
#  ((u'hours',), 17),
#  ((u'likely',), 17),
#  ((u'herself',), 17),
#  ((u'coat',), 17),
#  ((u'frauds',), 17),
#  ((u'making',), 17),
#  ((u'turns',), 17),
#  ((u'spoon',), 17),
#  ((u'mine',), 17),
#  ((u'its',), 17),
#  ((u'afraid',), 17),
#  ((u'outside',), 17),
#  ((u'wreck',), 17),
#  ((u'walk',), 16),
#  ((u'hang',), 16),
#  ((u'telling',), 16),
#  ((u'um',), 16),
#  ((u'truck',), 16),
#  ((u'lie',), 16),
#  ((u'lose',), 16),
#  ((u'kings',), 16),
#  ((u'clumb',), 16),
#  ((u'_',), 16),
#  ((u'yards',), 16),
#  ((u'eye',), 16),
#  ((u'miles',), 16),
#  ((u'account',), 16),
#  ((u'lived',), 16),
#  ((u'sister',), 16),
#  ((u'waked',), 16),
#  ((u'stuff',), 16),
#  ((u'sung',), 16),
#  ((u'worse',), 16),
#  ((u'wild',), 16),
#  ((u'thatcher',), 16),
#  ((u'mostly',), 16),
#  ((u'letting',), 16),
#  ((u'shucks',), 16),
#  ((u'quarter',), 16),
#  ((u'towhead',), 16),
#  ((u'real',), 16),
#  ((u'crying',), 16),
#  ((u'laughed',), 16),
#  ((u'death',), 16),
#  ((u'snakes',), 16),
#  ((u'noise',), 16),
#  ((u'knows',), 16),
#  ((u'lonesome',), 15),
#  ((u'takes',), 15),
#  ((u'boggs',), 15),
#  ((u'fur',), 15),
#  ((u'quit',), 15),
#  ((u'ef',), 15),
#  ((u'having',), 15),
#  ((u'inside',), 15),
#  ((u'louis',), 15),
#  ((u'smoke',), 15),
#  ((u'witches',), 15),
#  ((u'except',), 15),
#  ((u'dis',), 15),
#  ((u'arm',), 15),
#  ((u'lawyer',), 15),
#  ((u'sich',), 15),
#  ((u'sings',), 15),
#  ((u'mos',), 15),
#  ((u'gets',), 15),
#  ((u'straw',), 15),
#  ((u'slip',), 15),
#  ((u'heah',), 15),
#  ((u'tight',), 15),
#  ((u'stayed',), 15),
#  ((u'begin',), 15),
#  ((u'mother',), 15),
#  ((u'setting',), 15),
#  ((u'illinois',), 15),
#  ((u'shoulder',), 15),
#  ((u'grabbed',), 15),
#  ((u'deal',), 15),
#  ((u'wide',), 15),
#  ((u'fence',), 15),
#  ((u'sense',), 15),
#  ((u'standing',), 15),
#  ((u'bread',), 15),
#  ((u'phelps',), 15),
#  ((u'others',), 15),
#  ((u'england',), 14),
#  ((u'sheet',), 14),
#  ((u'watched',), 14),
#  ((u'blue',), 14),
#  ((u'beat',), 14),
#  ((u'notion',), 14),
#  ((u'paddle',), 14),
#  ((u'nine',), 14),
#  ((u'fault',), 14),
#  ((u'dream',), 14),
#  ((u'soft',), 14),
#  ((u'uneasy',), 14),
#  ((u'pay',), 14),
#  ((u'funeral',), 14),
#  ((u'letters',), 14),
#  ((u'break',), 14),
#  ((u'chain',), 14),
#  ((u'books',), 14),
#  ((u"ain't",), 14),
#  ((u'played',), 14),
#  ((u'kin',), 14),
#  ((u'since',), 14),
#  ((u'sah',), 14),
#  ((u'wants',), 14),
#  ((u'rode',), 14),
#  ((u'handy',), 14),
#  ((u"it's",), 14),
#  ((u'brass',), 14),
#  ((u'held',), 14),
#  ((u'chaw',), 14),
#  ((u'kinds',), 14),
#  ((u'leaves',), 14),
#  ((u'friends',), 14),
#  ((u'knees',), 14),
#  ((u'nearly',), 14),
#  ((u'gentlemen',), 14),
#  ((u'him.',), 14),
#  ((u'_they_',), 14),
#  ((u'liked',), 14),
#  ((u'forty',), 14),
#  ((u'didn',), 14),
#  ((u'orleans',), 14),
#  ((u'son',), 14),
#  ((u'state',), 13),
#  ((u'signs',), 13),
#  ((u'save',), 13),
#  ((u'hungry',), 13),
#  ((u'snake',), 13),
#  ((u'flung',), 13),
#  ((u'hot',), 13),
#  ((u'ornery',), 13),
#  ((u'opened',), 13),
#  ((u'breast',), 13),
#  ((u'wouldn',), 13),
#  ((u'cussing',), 13),
#  ((u'le',), 13),
#  ((u'few',), 13),
#  ((u'play',), 13),
#  ((u'style',), 13),
#  ((u'yo',), 13),
#  ((u'hunted',), 13),
#  ((u'wilks',), 13),
#  ((u'alive',), 13),
#  ((u'twenty',), 13),
#  ((u'tie',), 13),
#  ((u"don't",), 13),
#  ((u'stranger',), 13),
#  ((u'blamed',), 13),
#  ((u'das',), 13),
#  ((u'bother',), 13),
#  ((u'weeks',), 13),
#  ((u'count',), 13),
#  ((u'short',), 13),
#  ((u'raise',), 13),
#  ((u'grindstone',), 13),
#  ((u'remember',), 13),
#  ((u'gold',), 13),
#  ((u'mad',), 13),
#  ((u'please',), 13),
#  ((u'fine',), 13),
#  ((u'taking',), 13),
#  ((u'jim.',), 13),
#  ((u'_now_',), 13),
#  ((u'ain',), 13),
#  ((u'breath',), 13),
#  ((u'wind',), 13),
#  ((u'borrow',), 13),
#  ((u'missed',), 13),
#  ((u'paddled',), 13),
#  ((u'cave',), 12),
#  ((u'putting',), 12),
#  ((u'slept',), 12),
#  ((u'jest',), 12),
#  ((u'govment',), 12),
#  ((u'fairly',), 12),
#  ((u"o'clock",), 12),
#  ((u'listen',), 12),
#  ((u'pray',), 12),
#  ((u'track',), 12),
#  ((u'whisky',), 12),
#  ((u'cry',), 12),
#  ((u'picture',), 12),
#  ((u'sky',), 12),
#  ((u'gray',), 12),
#  ((u'lady',), 12),
#  ((u'midnight',), 12),
#  ((u'looks',), 12),
#  ((u'kinder',), 12),
#  ((u'child',), 12),
#  ((u'candles',), 12),
#  ((u'wrong',), 12),
#  ((u'polly',), 12),
#  ((u'_do_',), 12),
#  ((u'fellow',), 12),
#  ((u'watching',), 12),
#  ((u'lovely',), 12),
#  ((u'cool',), 12),
#  ((u'rip',), 12),
#  ((u'law',), 12),
#  ((u'logs',), 12),
#  ((u'_that_',), 12),
#  ((u'un',), 12),
#  ((u'months',), 12),
#  ((u'school',), 12),
#  ((u'drop',), 12),
#  ((u'true',), 12),
#  ((u'sweet',), 12),
#  ((u'fooling',), 12),
#  ((u'houses',), 12),
#  ((u'twice',), 12),
#  ((u'eight',), 12),
#  ((u'cairo',), 12),
#  ((u'dressed',), 12),
#  ((u'wake',), 12),
#  ((u'learn',), 12),
#  ((u'tearing',), 12),
#  ((u'yes.',), 12),
#  ((u'truth',), 11),
#  ((u'po',), 11),
#  ((u'pulled',), 11),
#  ((u'one.',), 11),
#  ((u'steps',), 11),
#  ((u'square',), 11),
#  ((u'air',), 11),
#  ((u'kitchen',), 11),
#  ((u'honey',), 11),
#  ((u'_got_',), 11),
#  ((u'buy',), 11),
#  ((u'yesterday',), 11),
#  ((u'me.',), 11),
#  ((u'st.',), 11),
#  ((u'cellar',), 11),
#  ((u'understand',), 11),
#  ((u'seven',), 11),
#  ((u'fish',), 11),
#  ((u'gracious',), 11),
#  ((u'tracks',), 11),
#  ((u'worry',), 11),
#  ((u'fifty',), 11),
#  ((u'cow',), 11),
#  ((u'tear',), 11),
#  ((u'early',), 11),
#  ((u'pull',), 11),
#  ((u'ourselves',), 11),
#  ((u'nuther',), 11),
#  ((u'stretched',), 11),
#  ((u'lights',), 11),
#  ((u'jist',), 11),
#  ((u'fun',), 11),
#  ((u'moon',), 11),
#  ((u'floating',), 11),
#  ((u'robbers',), 11),
#  ((u'troubles',), 11),
#  ((u'sing',), 11),
#  ((u'lid',), 11),
#  ((u'lightning-rod',), 11),
#  ((u'questions',), 11),
#  ((u'reward',), 11),
#  ((u'laugh',), 11),
#  ((u'slide',), 11),
#  ((u'speech',), 11),
#  ((u'voice',), 11),
#  ((u'somewheres',), 11),
#  ((u'gim',), 11),
#  ((u"couldn't",), 11),
#  ((u'weather',), 11),
#  ((u'shed',), 11),
#  ((u'generly',), 11),
#  ((u"'long",), 11),
#  ((u'part',), 11),
#  ((u'change',), 11),
#  ((u'tuck',), 11),
#  ((u'rolled',), 10),
#  ((u'rush',), 10),
#  ((u'dozen',), 10),
#  ((u'time.',), 10),
#  ((u'nonesuch',), 10),
#  ((u'near',), 10),
#  ((u'daytime',), 10),
#  ((u'legs',), 10),
#  ((u'pens',), 10),
#  ((u'watermelon',), 10),
#  ((u'ruther',), 10),
#  ((u'overboard',), 10),
#  ((u'edge',), 10),
#  ((u'names',), 10),
#  ((u'hare-lip',), 10),
#  ((u'crossed',), 10),
#  ((u'whatever',), 10),
#  ((u'even',), 10),
#  ((u'thirty',), 10),
#  ((u'shepherdsons',), 10),
#  ((u'streak',), 10),
#  ((u'property',), 10),
#  ((u'street',), 10),
#  ((u'fair',), 10),
#  ((u'seeing',), 10),
#  ((u'rock',), 10),
#  ((u'uncles',), 10),
#  ((u'rough',), 10),
#  ((u'pictures',), 10),
#  ((u'cavern',), 10),
#  ((u'circus',), 10),
#  ((u'jackson',), 10),
#  ((u'great',), 10),
#  ((u'key',), 10),
#  ((u'lots',), 10),
#  ((u'wisht',), 10),
#  ((u'nation',), 10),
#  ((u'pan',), 10),
#  ((u'oars',), 10),
#  ((u'blanket',), 10),
#  ((u'pick',), 10),
#  ((u'bilgewater',), 10),
#  ...]

# %%
from jargon_distance.analysis import JargonDistanceAnalysis

# %%
# j.write_to_file('tjd.csv')

# %%
ja = JargonDistanceAnalysis().from_object(j)

# %%
ja.symmetrize_graph()

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ja.get_linkage(method='average')
# Out:
# array([[ 0.        ,  3.        ,  0.04501269,  2.        ],
#        [ 1.        ,  4.        ,  0.05866477,  2.        ],
#        [ 2.        ,  5.        ,  0.06143286,  2.        ],
#        [ 6.        ,  7.        ,  0.06579069,  4.        ],
#        [ 8.        ,  9.        ,  0.09475491,  6.        ]])

# %%
ja.make_dendrogram(labels=ja.G_sym.nodes(), show_plot=True, rotation=90.)
# Out:
# (<matplotlib.figure.Figure at 0x7f0e9c64d510>,
#  {'color_list': ['g', 'r', 'r', 'r', 'b'],
#   'dcoord': [[0.0, 0.061432856115133494, 0.061432856115133494, 0.0],
#    [0.0, 0.045012686706013216, 0.045012686706013216, 0.0],
#    [0.0, 0.058664772087420547, 0.058664772087420547, 0.0],
#    [0.045012686706013216,
#     0.065790688803641556,
#     0.065790688803641556,
#     0.058664772087420547],
#    [0.061432856115133494,
#     0.094754913410739855,
#     0.094754913410739855,
#     0.065790688803641556]],
#   'icoord': [[5.0, 5.0, 15.0, 15.0],
#    [25.0, 25.0, 35.0, 35.0],
#    [45.0, 45.0, 55.0, 55.0],
#    [30.0, 30.0, 50.0, 50.0],
#    [10.0, 10.0, 40.0, 40.0]],
#   'ivl': ['William Shakespeare - Othello',
#    'William Shakespeare - As You Like It',
#    'Mark Twain - The Adventures of Huckleberry Finn',
#    'Mark Twain - The Adventures of Tom Sawyer',
#    'Charles Dickens - Oliver Twist',
#    'Charles Dickens - A Christmas Carol'],
#   'leaves': [2, 5, 0, 3, 1, 4]})

# %%
cm = ja.make_sns_clustermap(labels=ja.G_sym.nodes(), show_plot=True, nonzero_diagonal=True)
# plt.show()
# fig.show()
# Out:
# /home/jporteno/anaconda2/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
cm = ja.make_sns_clustermap(labels=ja.G_sym.nodes())
# plt.show()
# fig.show()
